# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np, os
import matplotlib.pyplot as plt

from pathlib import Path
import yaml
import re
import datetime

import pyarrow as pa
import pyarrow.parquet as pq

import gbd_mapping as gm
from vivarium import Artifact

from db_queries import get_ids, get_outputs, get_population, get_covariate_estimates
from get_draws.api import get_draws

import vivarium_helpers as vh
import vivarium_helpers.id_helper as idh
from vivarium_helpers.vph_output.operations import VPHOperator
from vivarium_helpers.vph_output.measures import VPHResults
from vivarium_helpers.utils import convert_to_categorical, constant_categorical, print_memory_usage
from vivarium_helpers.vph_output import cleaning

# !date
# !whoami
# !pwd
# Out:
# Sun Nov  2 16:39:37 PST 2025
# ndbs
# /mnt/share/code/ndbs/vivarium_research_alzheimers/results_tables

# %% [markdown]
# # Find data
#
# Results directories of final model 8.4 runs, in batches of 3 or 4 draws:
#
# Batch 0 results:
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_39_18
#
# Batch 1 results:
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_41_39
#
# Batch 2 results:
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_45_13
#
# Batch 3 results:
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_14_03_51
#
# Batch 4 results:
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_16_32_03
#
# Batch 5 results:
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_17_25_38
#
# Batch 6 results:
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_03_40
#
# Batch 7 results:
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_09_31

# %%
# Model 8.4 results (final run for 10/31 intermediate results)
# Each batch run contains all locations, 100 random seeds, and 3 or 4 draws
batch_run_dirs = [
    '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_39_18',
    '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_41_39', # deduplicated
    '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_45_13', # 4 draws
    '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_14_03_51',
    '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_16_32_03',
    '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_17_25_38',
    '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_03_40',
    '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_09_31',
]

batch_results_dirs = []
for run_dir in batch_run_dirs:
    if run_dir.endswith('2025_10_29_20_41_39'):
        # One batch had to be deduplicated
        results_dir = run_dir + '/deduplicated_results'
    else:
        results_dir = run_dir + '/results'
    batch_results_dirs.append(results_dir)
batch_results_dirs

# batch_results_dirs = batch_results_dirs[:3] # filter for testing
batch_results_dirs
# Out:
# ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_39_18/results',
#  '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_41_39/deduplicated_results',
#  '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_45_13/results',
#  '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_14_03_51/results',
#  '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_16_32_03/results',
#  '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_17_25_38/results',
#  '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_03_40/results',
#  '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_09_31/results']

# %%
# Project directory
# %cd /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/
# Out:
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers

# %%
# Results directory containing model 8.3 results for all locations (for testing)
model_run_subdir = 'results/abie_consistent_model_test/united_states_of_america/2025_10_28_08_55_05/'
# !ls -halt $model_run_subdir/results
# Out:
# total 60M
# drwxrwsr-x 5 abie IHME-Simulationscience 4.5K Oct 28 09:19 ..
# drwxrwsr-x 2 abie IHME-Simulationscience 6.5K Oct 28 09:17 .
# -rw-rw-r-- 1 abie IHME-Simulationscience  17M Oct 28 09:17 ylds.parquet
# -rw-rw-r-- 1 abie IHME-Simulationscience 8.2M Oct 28 09:17 ylls.parquet
# -rw-rw-r-- 1 abie IHME-Simulationscience 5.2M Oct 28 09:17 person_time_treatment.parquet
# -rw-rw-r-- 1 abie IHME-Simulationscience 512K Oct 28 09:17 counts_newly_eligible_for_bbbm_testing.parquet
# -rw-rw-r-- 1 abie IHME-Simulationscience 794K Oct 28 09:17 person_time_eligible_for_bbbm_testing.parquet
# -rw-rw-r-- 1 abie IHME-Simulationscience 1.4M Oct 28 09:17 deaths.parquet
# -rw-rw-r-- 1 abie IHME-Simulationscience 4.1M Oct 28 09:17 person_time_ever_eligible_for_bbbm_testing.parquet
# -rw-rw-r-- 1 abie IHME-Simulationscience 841K Oct 28 09:17 counts_new_simulants.parquet
# -rw-rw-r-- 1 abie IHME-Simulationscience 406K Oct 28 09:17 counts_bbbm_tests.parquet
# -rw-rw-r-- 1 abie IHME-Simulationscience 2.4M Oct 28 09:17 counts_baseline_tests_among_eligible.parquet
# -rw-rw-r-- 1 abie IHME-Simulationscience 5.4M Oct 28 09:17 transition_count_alzheimers_disease_and_other_dementias.parquet
# -rw-rw-r-- 1 abie IHME-Simulationscience 1.1M Oct 28 09:16 transition_count_treatment.parquet
# -rw-rw-r-- 1 abie IHME-Simulationscience  14M Oct 28 09:16 person_time_alzheimers_disease_and_other_dementias.parquet

# %%
# !ls artifacts
# Out:
# 2		  model1.0  model3.0  model4.1	model4.4  model6.0
# basic_model	  model2.0  model3.1  model4.2	model4.5  model7.0
# consistent-rates  model2.2  model4.0  model4.3	model5.0  model8.3

# %%
# This is where results will eventually be for the 8.4 final runs
# !ls results/model8.4/model_spec
# Out:
# 2025_10_29_20_39_18  2025_10_30_14_03_51  2025_10_31_01_03_40
# 2025_10_29_20_41_39  2025_10_30_16_32_03  2025_10_31_01_09_31
# 2025_10_29_20_45_13  2025_10_30_17_25_38

# %% [markdown]
# # Define directories
#
# ### Output directory:
#
# `J:\Project\simulation_science\alzheimers\results_10_31_2025`

# %%
output_dir = Path(r"J:\Project\simulation_science\alzheimers\results_10_31_2025".replace('\\', '/').replace('J:', '/snfs1'))
print(output_dir.exists())
output_dir
# Out:
# True
# PosixPath('/snfs1/Project/simulation_science/alzheimers/results_10_31_2025')

# %%
locations = [
    'United States of America',
    'Brazil',
    'China',
    'Germany',
    'Israel',
    'Japan',
    'Spain',
    'Sweden',
    'Taiwan (Province of China)',
    'United Kingdom',
]

# Define some shorter names to use for plotting
location_to_short_name = ({loc: loc for loc in locations}| {
    'Taiwan (Province of China)': 'Taiwan',
    'United Kingdom': 'UK',
    'United States of America': 'USA',
})

# Select a subset of locations to draw plots for
locations_to_plot = locations[:2]

project_dir = '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/'

artifact_model_number = '8.3' # Artifacts are stored here
# run_subdirectories = [
#     model_run_subdir,
# ]
# run_dirs = [project_dir + run_subdir for run_subdir in run_subdirectories]
# results_dirs = [run_dir + 'results/' for run_dir in run_dirs]

# Results directory for model 8.3, for testing
results_dirs = project_dir + model_run_subdir + 'results/'

def get_results_and_artifact_dicts(
        locations, results_dirs, artifact_model_number, project_dir):

    match results_dirs:
        case str() | Path():
            # Option 1: All locations concatenated in one results
            # directory
            location_to_results_dir = {'all': results_dirs}
        case list():
            # Option 2: One results directory per location
            location_to_results_dir = {
                loc: path for loc, path in zip(locations, results_dirs)}

    location_to_artifact_subdir = {
        loc: loc.lower().replace(' ', '_') for loc in locations}
    artifact_subpaths = [
        f'artifacts/model{artifact_model_number}/' + subdir + '.hdf' 
        for subdir in location_to_artifact_subdir.values()]

    location_to_artifact_path = {
        loc: project_dir + subpath for loc, subpath
        in zip(locations, artifact_subpaths)}

    return location_to_results_dir, location_to_artifact_path

location_to_results_dir, location_to_artifact_path = get_results_and_artifact_dicts(
    locations, results_dirs, artifact_model_number, project_dir
)
location_to_artifact_path
# Out:
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf',
#  'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf',
#  'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf',
#  'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf',
#  'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf',
#  'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf',
#  'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf',
#  'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf',
#  'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf',
#  'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}

# %%
location_to_results_dir
# Out:
# {'all': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/abie_consistent_model_test/united_states_of_america/2025_10_28_08_55_05/results/'}

# %% [markdown]
# # Define some ordered Categorical dtypes, and convert years to ints

# %%
# Order locations lexicographically
all_locations = [
    'United States of America',
    'Brazil',
    'China',
    'Germany',
    'Israel',
    'Japan',
    'Spain',
    'Sweden',
    'Taiwan (Province of China)',
    'United Kingdom',
]
all_locations_dtype = pd.CategoricalDtype(sorted(all_locations), ordered=True)

# int16 ranges from -32768 to 32767 (I think), which is sufficient to
# represent all years 2025-2100. uint8 only goes from 0 to 255, which is
# too small.
year_dtype = 'int16'

# Store draws as ints instead of categoricals since we'll be
# concatenating different draws from different results directories
input_draw_dtype = 'int16'

# Order age groups chronologically
age_groups = [f'{age}_to_{age + 4}' for age in range(25, 95, 5)] + ['95_plus']
age_group_dtype = pd.CategoricalDtype(age_groups, ordered=True)

# Order scenarios by complexity
scenarios = ['baseline', 'bbbm_testing', 'bbbm_testing_and_treatment']
scenario_dtype = pd.CategoricalDtype(scenarios, ordered=True)

colname_to_dtype = {
    'location': all_locations_dtype,
    'event_year': year_dtype,
    'age_group': age_group_dtype,
    'scenario': scenario_dtype,
    'input_draw': input_draw_dtype,
}

# %% [markdown]
# # Load one artifact to define age bins

# %%
artifact_path = location_to_artifact_path[locations[0]]
art = Artifact(artifact_path)
print(art.load('metadata.locations'))

# age_bins is an empty DataFrame with a MultiIndex storing age group data
age_bins = art.load('population.age_bins')
age_map = (
    age_bins
    .reset_index()
    .assign(age_group=lambda df: df['age_group_name'].str.replace(' ', '_'))
    # Filter to ages that actually appear in our sim
    .query("age_start >= 25")
)
age_map.tail()
# Out:
# ['United States of America']
#     age_group_id age_group_name  age_start  age_end age_group
# 14            20       75 to 79       75.0     80.0  75_to_79
# 15            30       80 to 84       80.0     85.0  80_to_84
# 16            31       85 to 89       85.0     90.0  85_to_89
# 17            32       90 to 94       90.0     95.0  90_to_94
# 18           235        95 plus       95.0    125.0   95_plus

# %% [markdown]
# # Define function to load and merge Artifact data from all locations

# %%
def load_artifact_data(
    key,
    filter_terms=None,
    location_to_artifact_path=location_to_artifact_path,
):
    dfs = {} # dict to map locations to artifact data
    for location, path in location_to_artifact_path.items():
        art = Artifact(path, filter_terms)
        # Check to make sure location matches artifact
        art_locations = art.load('metadata.locations')
        assert len(art_locations) == 1 and art_locations[0] == location, \
            f'Unexpected locations in artifact: {location=}, {art_locations=}'
        df = art.load(key)
        dfs[location] = df
    if all('location' in df.index.names for df in dfs.values()):
        data = pd.concat(dfs.values())
    else:
        data = pd.concat(dfs, names=['location', *df.index.names])
    return data

# %% [markdown]
# # Define functions to load simulation results

# %%
# Create an operator object - treat each random seed as a separate draw,
# and add location to the index
ops = VPHOperator(location_col=True)
# ops.index_cols.extend(['location', 'random_seed'])

def load_sim_output(
        measure,
        results_dict=location_to_results_dir,
        # Pass None to skip filtering locations (when None, must also
        # pass assign_location=False or raw=True)
        location_to_artifact_path=location_to_artifact_path,
        # specify dtypes of certain columns
        colname_to_dtype=colname_to_dtype,
        drop_superfluous_cols=True, # drop redundant or empty columns
        # Sets the 'read_dictionary' key of kwargs, which is passed to
        # pyarrow.parquet.read_table()
        force_parquet_dictionaries=True,
        force_pandas_categoricals=True,
        aggregate_seeds=True,
        assign_location=True,
        raw=False, # Overrides other parameters if True
        **kwargs, # keyword args to pass to .read_parquet
    ):
    """Load simulation output from .parquet files for all locations,
    optionally reducing the size of the data when possible. Returns
    concatenated outputs with a 'location' column added.
    """
    # Override optional transformations if raw=True
    if raw:
        drop_superfluous_cols = False
        force_parquet_dictionaries = False
        force_pandas_categoricals = False
        aggregate_seeds = False
        assign_location = False

    # Determine whether results for all locations are stored in same
    # directory, or if different locations have different results
    # directories
    match location_to_results_dir:
        case {'all': _}:
            all_locations_together = True
        case _:
            all_locations_together = False
    
    if all_locations_together and assign_location and location_to_artifact_path is None:
        raise ValueError(
            "Must provide mapping of artifacts to locations  when" \
            " assign_location=True and all locations are concatenated" \
            " in the simulation outputs."
        )

    dfs = []
    for location, directory in results_dict.items():

        parquet_file_path = Path(directory) / f'{measure}.parquet'
        # Read the Parquet file's schema to get column names and data types
        parquet_schema = pq.read_schema(parquet_file_path)

        if (
            all_locations_together
            and location_to_artifact_path is not None
        ):
            if 'artifact_path' in parquet_schema.names:
                # Filter to locations in list
                location_filter = (
                    'artifact_path',
                    'in',
                    list(location_to_artifact_path.values()),
                )
                user_filters = kwargs.get('filters') # Defaults to None
                kwargs['filters'] = add_parquet_AND_filter(
                    location_filter, user_filters)
                # TODO: Use logging not printing
                print(location_filter)
            else:
                print("'artifact_path' column missing from parquet file."
                      " Not filtering locations.")

        if force_parquet_dictionaries:
            # Read all columns as dictionaries except those containing 
            # floating point values
            kwargs['read_dictionary'] = [
                col.name for col in parquet_schema
                if not pa.types.is_floating(col.type)]

        # Read the parquet file
        df = pd.read_parquet(parquet_file_path, **kwargs)
        print_memory_usage(df, 'after read_parquet')

        if drop_superfluous_cols:
            # Drop redundant columns
            for col1, col2 in [
                ('input_draw', 'input_draw_number'),
                ('entity', 'sub_entity'),
            ]:
                if (col1 in df and col2 in df and df[col1].equals(df[col2])):
                    df.drop(columns=col2, inplace=True)
            # Drop empty columns (e.g., sub-entity)
            for col in df:
                if df[col].isna().all():
                    df.drop(columns=col, inplace=True)
        if colname_to_dtype is not None:
            df = df.astype(
                # Filter to avoid KeyError
                {c: dtype for c, dtype
                 in colname_to_dtype.items() if c in df},
                 # NOTE: If copy-on-write is enabled, copy keyword is
                 # ignored
                 copy=False)
        if force_pandas_categoricals:
            convert_to_categorical(
                df, exclude_cols=colname_to_dtype or (), inplace=True)
        if aggregate_seeds:
            # Use default index and value columns when aggregating
            df = vh.vph_output.operations.marginalize(df, 'random_seed')
        if assign_location:
            if all_locations_together:
                # NOTE: location_to_artifact_path is guaranteed not to
                # be None because assign_location and
                # all_locations_together are both True

                # Find or create a Categorical dtype with all locations
                location_dtype = colname_to_dtype.get(
                    'location',
                    pd.CategoricalDtype(
                        sorted(location_to_artifact_path.keys()), ordered=True)
                )
                # Invert the dictionary so we can map artifact paths to
                # locations
                artifact_path_to_location = {
                    path: loc for loc, path
                    in location_to_artifact_path.items()}
                if 'artifact_path' in df:
                    df['location'] = df['artifact_path'].map(
                        artifact_path_to_location).astype(location_dtype)
                else:
                    # In case the engineers change the DataFrame format
                    # on us...
                    print("'artifact_path' column missing from DataFrame."
                          " Not assigning locations.")
            else:
                # NOTE: location_to_results_dir contains actual
                # locations as keys (not 'all') since
                # all_locations_together is False

                # Find or create a Categorical dtype with all locations
                # to avoid converting back to object dtype.
                location_dtype = colname_to_dtype.get(
                    'location',
                    pd.CategoricalDtype(
                        sorted(location_to_results_dir.keys()), ordered=True)
                )
                df['location'] = location
                df['location'] = df['location'].astype(location_dtype)
        dfs.append(df)
    # TODO: Maybe if assign_location is False and all_locations_together
    # is also False (and there is more than one location?), we should
    # return a dict mapping locations to dataframes (or just a list of
    # dataframes?) instead of concatenating, since it won't be possible
    # to filter the resulting concatenated dataframe by location...
    df = pd.concat(dfs, ignore_index=True)
    return df
    
def add_parquet_AND_filter(new_filter, existing_filters):
    match existing_filters:
        case None:
            # No existing filters -- create a single AND group
            filters = [new_filter]
        case list([tuple((_, _, _)), *_]):
            # Existing filters consist of one AND group -- add the new filter
            filters = [new_filter, *existing_filters]
        case list([list([tuple((_, _, _)), *_]), *_]):
            # Add the filter to each AND group in the outer OR group
            filters = [[new_filter, *and_group] for and_group in existing_filters]
        case _:
            raise ValueError(f"Malformed parquet filter: {existing_filters}")
    return filters

def current_time():
    print(datetime.datetime.now())

# %% [markdown]
# ## Function to load and concatenate runs from multiple batches
#
# It's possible that loading all locations at once from a single batch may
# use too much memory, so we may have to load locations in groups from
# each batch before we can aggregate random seeds to make the data smaller.

# %%
# Test grouping locations into n groups:
# This seems to work for any n and splits as evenly as possible,
# front-loading with larger groups at the beginning
n = 4
for i in range(n):
    print(locations[i::n])
# Out:
# ['United States of America', 'Israel', 'Taiwan (Province of China)']
# ['Brazil', 'Japan', 'United Kingdom']
# ['China', 'Spain']
# ['Germany', 'Sweden']

# %%
def load_measure_from_batch_runs(
        measure,
        batch_results_dirs,
        locations=locations,
        n_location_groups=1,
        colname_to_dtype=colname_to_dtype,
        project_dir=project_dir,
        **kwargs
    ):
    """Load data from multiple batch runs, aggregate random seeds, and
    concatenate.
    """
    # aggregate seeds by default, and warn if False was passed
    if not kwargs.setdefault('aggregate_seeds', True):
        # Documentation for setdefault: If key is in the dictionary,
        # return its value. If not, insert key with a value of default
        # and return default.
        print("Warning: Not aggregating seeds, which may require lots of memory")
    dfs = []
    for results_dir in batch_results_dirs:
        print(results_dir)
        for i in range(n_location_groups):
            location_group = locations[i::n_location_groups]
            # print(location_group)
            location_to_results_dir, location_to_artifact_path = get_results_and_artifact_dicts(
                location_group, results_dir, artifact_model_number, project_dir
            )
            print(location_to_artifact_path)
            df = load_sim_output(
                measure, location_to_results_dir, location_to_artifact_path, colname_to_dtype, **kwargs
            )
            print_memory_usage(df, 'after aggregating seeds and converting dtypes')
            dfs.append(df)
    measure_df = pd.concat(dfs, ignore_index=True)
    print_memory_usage(measure_df, 'total')
    measure_df = measure_df.astype(colname_to_dtype)
    print_memory_usage(measure_df, 'after enforcing dtypes')
    return measure_df

# %%
batch_results_dirs[1:3]
# Out:
# ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_41_39/deduplicated_results',
#  '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_45_13/results']

# %%
# Stats for reading deaths.parquet with no extra filters:
# 28 seconds to load 2 batches with 1 location group, 20 MB after concatenation,
# max 1877 MB before aggregating seeds
# 31 seconds to load 2 batches with 3 location groups, 86 MB after concatenation,
# max 751 MB before aggregating seeds
test = load_measure_from_batch_runs(
    'deaths', batch_results_dirs[1:3], locations, n_location_groups=1
)
test.dtypes
# Out:
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_41_39/deduplicated_results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 1749.071711 MB after read_parquet
# 8.537636 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_45_13/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 1877.051843 MB after read_parquet
# 11.381636 MB after aggregating seeds and converting dtypes
# 19.913636 MB total
# 19.913636 MB after enforcing dtypes
# age_group        category
# artifact_path    category
# entity           category
# entity_type      category
# event_year          int16
# input_draw          int16
# measure          category
# scenario         category
# sex              category
# value             float64
# location         category
# dtype: object

# %% [markdown]
# # Calculate model scale
#
# ## First read population structure and initial all-state prevalences from the artifact

# %%
# This is the number of people in each demographic group in each year --
# these numbers come from the FHS population forecasts
pop_structure = load_artifact_data('population.structure')
pop_structure.tail()
# Out:
#                                                                   draw_0  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      129365.649457
#                                       2047       2048      129176.872428
#                                       2048       2049      128215.394230
#                                       2049       2050      127765.330292
#                                       2050       2051      128213.393685
#
#                                                                   draw_1  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      130775.330848
#                                       2047       2048      131427.429524
#                                       2048       2049      131705.587524
#                                       2049       2050      131992.359105
#                                       2050       2051      133220.130675
#
#                                                                   draw_2  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      132470.262731
#                                       2047       2048      133135.096509
#                                       2048       2049      132988.854403
#                                       2049       2050      132745.174212
#                                       2050       2051      133421.143899
#
#                                                                   draw_3  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      122141.117458
#                                       2047       2048      122206.362659
#                                       2048       2049      121848.151327
#                                       2049       2050      121566.569294
#                                       2050       2051      122248.029681
#
#                                                                   draw_4  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      122669.816649
#                                       2047       2048      121990.475534
#                                       2048       2049      120928.626569
#                                       2049       2050      120010.799977
#                                       2050       2051      119754.120437
#
#                                                                   draw_5  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      116553.291993
#                                       2047       2048      116216.514579
#                                       2048       2049      115242.163772
#                                       2049       2050      114127.489703
#                                       2050       2051      113654.996368
#
#                                                                   draw_6  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      137240.957664
#                                       2047       2048      137226.419110
#                                       2048       2049      136633.081048
#                                       2049       2050      136240.266101
#                                       2050       2051      136919.776385
#
#                                                                   draw_7  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      146303.198839
#                                       2047       2048      147381.840121
#                                       2048       2049      147552.139040
#                                       2049       2050      147709.447517
#                                       2050       2051      148869.875216
#
#                                                                   draw_8  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      134355.643238
#                                       2047       2048      134405.091989
#                                       2048       2049      133626.750369
#                                       2049       2050      133317.489612
#                                       2050       2051      133983.846752
#
#                                                                   draw_9  ...  \
# location       sex  age_start age_end year_start year_end                 ...
# United Kingdom Male 95.0      125.0   2046       2047      129130.125638  ...
#                                       2047       2048      128844.029807  ...
#                                       2048       2049      127966.248102  ...
#                                       2049       2050      127169.484355  ...
#                                       2050       2051      126969.448946  ...
#
#                                                                 draw_490  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      129199.724763
#                                       2047       2048      128743.759762
#                                       2048       2049      127782.664392
#                                       2049       2050      127529.973622
#                                       2050       2051      128519.079730
#
#                                                                 draw_491  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      133834.848564
#                                       2047       2048      134732.739968
#                                       2048       2049      134921.061786
#                                       2049       2050      135115.785472
#                                       2050       2051      135934.950475
#
#                                                                 draw_492  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      128153.198273
#                                       2047       2048      129357.417043
#                                       2048       2049      129793.897779
#                                       2049       2050      130017.373330
#                                       2050       2051      130583.543525
#
#                                                                 draw_493  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      126410.768209
#                                       2047       2048      127365.126985
#                                       2048       2049      127858.445137
#                                       2049       2050      128346.358923
#                                       2050       2051      129590.537377
#
#                                                                 draw_494  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      108873.787649
#                                       2047       2048      108980.704141
#                                       2048       2049      108759.061860
#                                       2049       2050      108768.814727
#                                       2050       2051      109219.537772
#
#                                                                 draw_495  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      129171.958392
#                                       2047       2048      128693.703184
#                                       2048       2049      127744.197044
#                                       2049       2050      127682.196818
#                                       2050       2051      128856.357034
#
#                                                                 draw_496  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      132812.650873
#                                       2047       2048      133430.947564
#                                       2048       2049      133723.530245
#                                       2049       2050      134255.130480
#                                       2050       2051      135299.299123
#
#                                                                 draw_497  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      145683.572345
#                                       2047       2048      146604.135918
#                                       2048       2049      146651.755678
#                                       2049       2050      146732.723463
#                                       2050       2051      147386.695970
#
#                                                                 draw_498  \
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      153951.857746
#                                       2047       2048      154047.335390
#                                       2048       2049      153534.536161
#                                       2049       2050      153968.447922
#                                       2050       2051      155815.638277
#
#                                                                 draw_499
# location       sex  age_start age_end year_start year_end
# United Kingdom Male 95.0      125.0   2046       2047      133969.822489
#                                       2047       2048      134464.260699
#                                       2048       2049      133964.837991
#                                       2049       2050      134047.815962
#                                       2050       2051      135717.268010
#
# [5 rows x 500 columns]

# %%
# For each demographic group, the "population scaling factor" is the
# ratio of the real-world population that we want to simulate in that
# group to the total number of people in that group. For Model 4 and
# above, this equals the initial prevalence of all AD disease states
# combined (preclinical + MCI + AD-dementia), since we are modeling the
# population of people with any stage of AD. Note that this is defined
# for the population at the beginning of the simulation, so there is
# only one year of data.
art_all_states_initial_prev = load_artifact_data('population.scaling_factor')
art_all_states_initial_prev.tail()
# NOTE: This data has two age groups, 95-100 and 100-105, instead of the
# single age group 95-125 that's in the population structure. I'm not
# sure why. I'm going to drop the 100-105 age group and match the 95-100
# age group with the 95-125 age group from above
# Out:
#                                                                draw_0  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.184057
#                       85        90      2025       2026      0.249261
#                       90        95      2025       2026      0.288238
#                       95        100     2025       2026      0.262417
#                       100       105     2025       2026      0.253172
#
#                                                                draw_1  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.205264
#                       85        90      2025       2026      0.251477
#                       90        95      2025       2026      0.285702
#                       95        100     2025       2026      0.263717
#                       100       105     2025       2026      0.257814
#
#                                                                draw_2  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.201615
#                       85        90      2025       2026      0.250982
#                       90        95      2025       2026      0.254878
#                       95        100     2025       2026      0.252117
#                       100       105     2025       2026      0.248932
#
#                                                                draw_3  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.203185
#                       85        90      2025       2026      0.279132
#                       90        95      2025       2026      0.292849
#                       95        100     2025       2026      0.276680
#                       100       105     2025       2026      0.272355
#
#                                                                draw_4  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.178318
#                       85        90      2025       2026      0.262662
#                       90        95      2025       2026      0.297609
#                       95        100     2025       2026      0.262065
#                       100       105     2025       2026      0.252686
#
#                                                                draw_5  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.175798
#                       85        90      2025       2026      0.236341
#                       90        95      2025       2026      0.266154
#                       95        100     2025       2026      0.260805
#                       100       105     2025       2026      0.253852
#
#                                                                draw_6  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.165233
#                       85        90      2025       2026      0.308766
#                       90        95      2025       2026      0.328095
#                       95        100     2025       2026      0.268706
#                       100       105     2025       2026      0.252204
#
#                                                                draw_7  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.152835
#                       85        90      2025       2026      0.292557
#                       90        95      2025       2026      0.294896
#                       95        100     2025       2026      0.252330
#                       100       105     2025       2026      0.245571
#
#                                                                draw_8  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.155335
#                       85        90      2025       2026      0.276890
#                       90        95      2025       2026      0.276581
#                       95        100     2025       2026      0.262280
#                       100       105     2025       2026      0.251487
#
#                                                                draw_9  ...  \
# location       sex    age_start age_end year_start year_end            ...
# United Kingdom Female 80        85      2025       2026      0.174561  ...
#                       85        90      2025       2026      0.286794  ...
#                       90        95      2025       2026      0.281861  ...
#                       95        100     2025       2026      0.255821  ...
#                       100       105     2025       2026      0.249820  ...
#
#                                                              draw_490  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.180658
#                       85        90      2025       2026      0.271585
#                       90        95      2025       2026      0.269374
#                       95        100     2025       2026      0.248522
#                       100       105     2025       2026      0.237925
#
#                                                              draw_491  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.197655
#                       85        90      2025       2026      0.290982
#                       90        95      2025       2026      0.263590
#                       95        100     2025       2026      0.244338
#                       100       105     2025       2026      0.215883
#
#                                                              draw_492  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.150986
#                       85        90      2025       2026      0.269875
#                       90        95      2025       2026      0.231749
#                       95        100     2025       2026      0.248601
#                       100       105     2025       2026      0.224073
#
#                                                              draw_493  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.137985
#                       85        90      2025       2026      0.259442
#                       90        95      2025       2026      0.222870
#                       95        100     2025       2026      0.242992
#                       100       105     2025       2026      0.222823
#
#                                                              draw_494  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.183084
#                       85        90      2025       2026      0.278545
#                       90        95      2025       2026      0.251981
#                       95        100     2025       2026      0.261974
#                       100       105     2025       2026      0.256208
#
#                                                              draw_495  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.153108
#                       85        90      2025       2026      0.276393
#                       90        95      2025       2026      0.253709
#                       95        100     2025       2026      0.263646
#                       100       105     2025       2026      0.267994
#
#                                                              draw_496  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.163890
#                       85        90      2025       2026      0.301692
#                       90        95      2025       2026      0.288297
#                       95        100     2025       2026      0.274336
#                       100       105     2025       2026      0.269680
#
#                                                              draw_497  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.135606
#                       85        90      2025       2026      0.294791
#                       90        95      2025       2026      0.272311
#                       95        100     2025       2026      0.246757
#                       100       105     2025       2026      0.248598
#
#                                                              draw_498  \
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.137780
#                       85        90      2025       2026      0.286761
#                       90        95      2025       2026      0.251585
#                       95        100     2025       2026      0.253818
#                       100       105     2025       2026      0.249409
#
#                                                              draw_499
# location       sex    age_start age_end year_start year_end
# United Kingdom Female 80        85      2025       2026      0.178453
#                       85        90      2025       2026      0.287763
#                       90        95      2025       2026      0.264228
#                       95        100     2025       2026      0.256388
#                       100       105     2025       2026      0.246543
#
# [5 rows x 500 columns]

# %%
# There's only one year worth of data here
art_all_states_initial_prev.index.unique('year_end')
# Out:
# Int64Index([2026], dtype='int64', name='year_end')

# %% [markdown]
# ## Now compute initial real-world all-state prevalence counts and model scale

# %%
def get_real_world_initial_population(
       population_structure,
       initial_prevalence,
       start_year=2022,
):
    years = initial_prevalence.index.unique('year_start')
    assert len(years) == 1, 'Unexpected years for initial prevalence!'
    year = years[0]
    # Use the specified start year for the population structure,
    # regardless of what single year is stored in the initial
    # prevalence. Rename year_start and year_end to properly match the
    # dataframes.
    initial_prevalence = (
        initial_prevalence
        .rename({year: start_year}, level='year_start')
        # NOTE: Only works if year_end = year_start + 1
        .rename({year+1: start_year+1}, level='year_end')
    )
    initial_prevalence_counts = (
        population_structure
        .query("year_start==@start_year")
        # Change end of oldest age group to match prevalence data
        .rename({125.0: 100.0}, level='age_end')
        * initial_prevalence
    ).dropna() # Drop age groups we don't have in sim
    return initial_prevalence_counts

art_all_states_initial_prev_counts = get_real_world_initial_population(
    pop_structure, art_all_states_initial_prev
)
art_all_states_initial_prev_counts.tail()
# Out:
#                                                                             draw_0  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      279503.716159
#                               80.0      85.0    2022       2023      295491.963153
#                               85.0      90.0    2022       2023      265660.836082
#                               90.0      95.0    2022       2023      135009.931912
#                               95.0      100.0   2022       2023       29288.078689
#
#                                                                             draw_1  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      241421.537335
#                               80.0      85.0    2022       2023      334542.816129
#                               85.0      90.0    2022       2023      279333.123360
#                               90.0      95.0    2022       2023      140544.500518
#                               95.0      100.0   2022       2023       30698.389085
#
#                                                                             draw_2  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      303005.456325
#                               80.0      85.0    2022       2023      352919.503418
#                               85.0      90.0    2022       2023      259372.093530
#                               90.0      95.0    2022       2023      117802.312175
#                               95.0      100.0   2022       2023       30107.564684
#
#                                                                             draw_3  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      245046.790482
#                               80.0      85.0    2022       2023      327523.755730
#                               85.0      90.0    2022       2023      273638.950137
#                               90.0      95.0    2022       2023      135061.861965
#                               95.0      100.0   2022       2023       32246.260410
#
#                                                                             draw_4  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      291032.019730
#                               80.0      85.0    2022       2023      309471.027115
#                               85.0      90.0    2022       2023      256249.409965
#                               90.0      95.0    2022       2023      138174.629778
#                               95.0      100.0   2022       2023       30766.214728
#
#                                                                             draw_5  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      292173.888069
#                               80.0      85.0    2022       2023      296260.437344
#                               85.0      90.0    2022       2023      220125.858697
#                               90.0      95.0    2022       2023      113243.661152
#                               95.0      100.0   2022       2023       29113.490401
#
#                                                                             draw_6  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      319151.434213
#                               80.0      85.0    2022       2023      265026.502337
#                               85.0      90.0    2022       2023      295555.094216
#                               90.0      95.0    2022       2023      140889.365668
#                               95.0      100.0   2022       2023       29413.069566
#
#                                                                             draw_7  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      322901.726876
#                               80.0      85.0    2022       2023      256594.636540
#                               85.0      90.0    2022       2023      283893.375460
#                               90.0      95.0    2022       2023      133342.913330
#                               95.0      100.0   2022       2023       29157.686021
#
#                                                                             draw_8  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      320919.877307
#                               80.0      85.0    2022       2023      268008.281527
#                               85.0      90.0    2022       2023      262971.486971
#                               90.0      95.0    2022       2023      123131.014317
#                               95.0      100.0   2022       2023       30052.152467
#
#                                                                             draw_9  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      312721.888359
#                               80.0      85.0    2022       2023      311310.859435
#                               85.0      90.0    2022       2023      293492.877529
#                               90.0      95.0    2022       2023      132526.382970
#                               95.0      100.0   2022       2023       30956.218671
#
#                                                                      ...  \
# location                 sex  age_start age_end year_start year_end  ...
# United States of America Male 75.0      80.0    2022       2023      ...
#                               80.0      85.0    2022       2023      ...
#                               85.0      90.0    2022       2023      ...
#                               90.0      95.0    2022       2023      ...
#                               95.0      100.0   2022       2023      ...
#
#                                                                           draw_490  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      340496.388986
#                               80.0      85.0    2022       2023      328352.211159
#                               85.0      90.0    2022       2023      304798.665607
#                               90.0      95.0    2022       2023      129627.305356
#                               95.0      100.0   2022       2023       32091.208571
#
#                                                                           draw_491  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      183624.796107
#                               80.0      85.0    2022       2023      321773.632827
#                               85.0      90.0    2022       2023      274423.347832
#                               90.0      95.0    2022       2023      108648.748859
#                               95.0      100.0   2022       2023       26499.605071
#
#                                                                           draw_492  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      303387.652317
#                               80.0      85.0    2022       2023      270912.872088
#                               85.0      90.0    2022       2023      285871.062247
#                               90.0      95.0    2022       2023      105907.707572
#                               95.0      100.0   2022       2023       31482.881082
#
#                                                                           draw_493  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      257740.083278
#                               80.0      85.0    2022       2023      241055.920798
#                               85.0      90.0    2022       2023      260618.321976
#                               90.0      95.0    2022       2023       95763.096448
#                               95.0      100.0   2022       2023       29952.989616
#
#                                                                           draw_494  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      264585.258062
#                               80.0      85.0    2022       2023      321904.097725
#                               85.0      90.0    2022       2023      271969.277566
#                               90.0      95.0    2022       2023      111257.383359
#                               95.0      100.0   2022       2023       32037.054667
#
#                                                                           draw_495  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      286707.666817
#                               80.0      85.0    2022       2023      272172.292983
#                               85.0      90.0    2022       2023      292854.234936
#                               90.0      95.0    2022       2023      119742.388165
#                               95.0      100.0   2022       2023       33926.196355
#
#                                                                           draw_496  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      288361.928754
#                               80.0      85.0    2022       2023      286599.286178
#                               85.0      90.0    2022       2023      324185.862549
#                               90.0      95.0    2022       2023      139285.777478
#                               95.0      100.0   2022       2023       34717.989582
#
#                                                                           draw_497  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      281653.836405
#                               80.0      85.0    2022       2023      235443.951067
#                               85.0      90.0    2022       2023      293051.854129
#                               90.0      95.0    2022       2023      121602.893171
#                               95.0      100.0   2022       2023       29169.491828
#
#                                                                           draw_498  \
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      283209.988963
#                               80.0      85.0    2022       2023      230842.759084
#                               85.0      90.0    2022       2023      265368.527577
#                               90.0      95.0    2022       2023      101618.235854
#                               95.0      100.0   2022       2023       28270.193829
#
#                                                                           draw_499
# location                 sex  age_start age_end year_start year_end
# United States of America Male 75.0      80.0    2022       2023      237124.856198
#                               80.0      85.0    2022       2023      276251.278427
#                               85.0      90.0    2022       2023      293529.464736
#                               90.0      95.0    2022       2023      117661.784595
#                               95.0      100.0   2022       2023       31345.616710
#
# [5 rows x 500 columns]

# %%
# Ininitial simulated population per draw, from concept model
# TODO: Change this to 100 seeds once we get final runs
num_seeds = 100 # 5 seeds for V&V runs, 100 seeds for final runs
pop_per_seed = 20_000
initial_sim_pop = num_seeds * pop_per_seed

def calculate_model_scale(
        simulated_initial_population,
        real_world_initial_population,
    ):
    # Sum over age groups to get real-world population in each location
    total_real_world_initial_pop = (
        real_world_initial_population.groupby('location').sum())
    # Model scale is the ratio of our simulated population to the real-world
    # population at time 0
    model_scale = (
        simulated_initial_population / total_real_world_initial_pop)
    # This format (draws horizontally as column names, as strings) is
    # compatible with Artifacts
    return model_scale

# Compute model scale in Artifact format
art_model_scale = calculate_model_scale(
    initial_sim_pop, art_all_states_initial_prev_counts)
art_model_scale
# Out:
#                                draw_0     draw_1     draw_2     draw_3  \
# location
# Brazil                       1.182478   1.062553   1.144685   1.078614
# China                        0.133424   0.130108   0.114296   0.115621
# Germany                      0.863308   0.892693   0.882412   0.879660
# Israel                      41.254628  40.310785  40.210343  40.057537
# Japan                        0.586866   0.574811   0.618108   0.553387
# Spain                        3.211223   3.418895   3.073433   2.871964
# Sweden                      13.614881  13.790971  11.796806  11.934329
# Taiwan (Province of China)   8.808232   7.720413   9.725660   8.515740
# United Kingdom               2.099057   2.036624   2.077655   2.012311
# United States of America     0.435214   0.429244   0.414357   0.431238
#
#                                draw_4     draw_5     draw_6     draw_7  \
# location
# Brazil                       1.082753   1.121963   1.003505   1.068713
# China                        0.123448   0.119143   0.117581   0.124027
# Germany                      0.779863   0.862006   0.874659   0.883173
# Israel                      39.166235  44.012209  35.797113  38.209922
# Japan                        0.564055   0.540442   0.488238   0.511745
# Spain                        3.086059   3.235590   2.882333   2.904501
# Sweden                      12.544275  12.395964  11.855079  13.491354
# Taiwan (Province of China)   8.443536   8.972456   8.809221   9.256961
# United Kingdom               2.061171   2.033260   2.023333   2.027407
# United States of America     0.427998   0.444600   0.417452   0.416229
#
#                                draw_8     draw_9  ...   draw_490   draw_491  \
# location                                          ...
# Brazil                       1.068239   1.220286  ...   1.290358   1.060123
# China                        0.115181   0.126465  ...   0.119680   0.125693
# Germany                      0.857328   0.946077  ...   0.948708   0.848518
# Israel                      41.226551  40.837404  ...  41.809532  40.213923
# Japan                        0.570487   0.564432  ...   0.536199   0.591534
# Spain                        3.250294   2.987198  ...   3.452614   3.070298
# Sweden                      13.650575  12.357657  ...  13.678809  12.871456
# Taiwan (Province of China)   7.936908   8.524695  ...   8.314534   8.305947
# United Kingdom               1.980920   1.990865  ...   1.905267   1.952344
# United States of America     0.423805   0.406953  ...   0.371698   0.461168
#
#                              draw_492   draw_493   draw_494   draw_495  \
# location
# Brazil                       1.086799   1.233531   0.984699   1.172564
# China                        0.127735   0.134309   0.126757   0.123859
# Germany                      0.866878   0.955230   0.949687   0.931259
# Israel                      40.180520  45.482468  47.228409  38.099635
# Japan                        0.595133   0.650132   0.621924   0.603336
# Spain                        3.679101   3.409524   3.012754   3.228092
# Sweden                      13.393983  14.436751  12.375910  11.803971
# Taiwan (Province of China)   8.938951   9.810819   9.125070   8.416122
# United Kingdom               2.208905   2.390574   2.156457   2.099913
# United States of America     0.424932   0.475658   0.453406   0.434504
#
#                              draw_496   draw_497   draw_498   draw_499
# location
# Brazil                       1.172570   1.039336   1.177133   1.124321
# China                        0.124902   0.119387   0.127926   0.123437
# Germany                      0.830667   0.891217   0.877104   0.868272
# Israel                      38.145320  34.621104  48.494263  40.043924
# Japan                        0.566684   0.576934   0.585316   0.567870
# Spain                        2.819038   2.934665   3.112781   3.208168
# Sweden                      12.878710  12.507280  14.370234  12.398862
# Taiwan (Province of China)   8.602790   8.931823   8.469918   8.560164
# United Kingdom               1.927622   2.024944   2.021172   2.005293
# United States of America     0.407813   0.435152   0.469132   0.445144
#
# [10 rows x 500 columns]

# %%
art_model_scale.T.describe()
# Out:
# location      Brazil       China     Germany      Israel       Japan  \
# count     500.000000  500.000000  500.000000  500.000000  500.000000
# mean        1.125453    0.123974    0.908049   41.107940    0.590351
# std         0.090995    0.007266    0.054319    3.488760    0.034167
# min         0.886671    0.103631    0.779863   32.489305    0.488238
# 25%         1.065282    0.119137    0.868970   38.763905    0.566227
# 50%         1.119439    0.123592    0.904125   40.838540    0.589194
# 75%         1.185735    0.127938    0.940060   43.150152    0.611063
# max         1.420375    0.151450    1.115194   55.030837    0.694869
#
# location       Spain      Sweden  Taiwan (Province of China)  United Kingdom  \
# count     500.000000  500.000000                  500.000000      500.000000
# mean        3.157002   13.113169                    8.800440        2.069689
# std         0.206373    0.842793                    0.522770        0.095687
# min         2.719273   10.915902                    7.563766        1.864453
# 25%         3.012984   12.456940                    8.444214        2.003624
# 50%         3.142980   13.091350                    8.792235        2.065020
# 75%         3.279462   13.654027                    9.145342        2.133291
# max         3.811998   15.716174                   10.479234        2.390574
#
# location  United States of America
# count                   500.000000
# mean                      0.440351
# std                       0.022943
# min                       0.371698
# 25%                       0.424886
# 50%                       0.439275
# 75%                       0.454833
# max                       0.542640

# %%
# Reformat model scale to be compatible with simulation output: draws
# vertically in columns or index, as integers

# model_scale = (
#     art_model_scale
#     .rename_axis(columns='input_draw')
#     .pipe(lambda df: df.set_axis(
#         df.columns.str.removeprefix('draw_')
#         .astype(input_draw_dtype), axis=1))
#     .stack()
#     .sort_index()
#     .rename('value')
#     .reset_index()
#     .astype({'location': all_locations_dtype})
# )

def convert_to_sim_format(df, colname_to_dtype=colname_to_dtype):
    """Convert artifact data to a format compatible with sim output."""
    # TODO: Also convert age_start/age_end to age_group
    # input_draw_dtype = colname_to_dtype.get('input_draw', 'int')
    # colname_to_dtype = {c: dtype for c, dtype
    #                     in colname_to_dtype.items() if c in df.index.names}
    new_df = (
        df
        .rename_axis(columns='input_draw')
        .rename(columns=lambda s: int(s.removeprefix('draw_')))
        .stack()
        # .sort_index()
        .rename('value')
        .rename_axis(index={'year_start': 'event_year'})
        .reset_index()
        # Drop the year_end column if it exists
        .drop(columns='year_end', errors='ignore')
        .pipe(lambda df: df.astype(
            {c: dtype for c, dtype
             in colname_to_dtype.items() if c in df}
        ))
    )
    return new_df

model_scale = convert_to_sim_format(art_model_scale)
model_scale
# Out:
#                       location  input_draw     value
# 0                       Brazil           0  1.182478
# 1                       Brazil           1  1.062553
# 2                       Brazil           2  1.144685
# 3                       Brazil           3  1.078614
# 4                       Brazil           4  1.082753
# ...                        ...         ...       ...
# 4995  United States of America         495  0.434504
# 4996  United States of America         496  0.407813
# 4997  United States of America         497  0.435152
# 4998  United States of America         498  0.469132
# 4999  United States of America         499  0.445144
#
# [5000 rows x 3 columns]

# %%
model_scale.dtypes
# Out:
# location      category
# input_draw       int16
# value          float64
# dtype: object

# %% [markdown]
# # Define functions to scale measures to real-world values, add rates, and generate final results

# %%
def scale_to_real_world(measure, model_scale=model_scale, ops=ops):
    """Divide the values in the `measure` dataframe by the values in
    `model_scale`, matching location and draw, and broadcasting across
    other columns in `measure`. This computes the value of the measure
    in the real-world population from the scaled-down version we get
    from the simulation.
    """
    draws = measure['input_draw'].unique()
    model_scale = model_scale.query("input_draw in @draws")
    measure = ops.value(measure)
    # NOTE: Reindexing preserves categoricals (in location column), but
    # results in all NaN's for some reason
    model_scale = ops.value(model_scale)#.reindex(measure.index)
    # scaled_measure = measure.divide(model_scale, axis=0).reset_index()
    scaled_measure = (measure / model_scale).reset_index()
    #.dropna() # Alternative to filtering draws above
    return scaled_measure

def calculate_rate(measure, population_structure=pop_structure, ops=ops):
    # Divide measure by total person time to get rate
    ...
    return measure

def summarize_and_beautify(
        df,
        # By default, assume disease stage is stored in sub_entity
        # column, but allow passing a different column
        disease_stage_column='sub_entity',
        # column_name_map={},
        model_scale=model_scale,
        population_structure=pop_structure,
        ops=ops,
    ):
    """Append rates, scale to real-world, summarize, rename columns,
    filter to desired columns, and put them in the right order.
    """
    # Calculate rates
    ...
    # Default column name map
    column_name_map = {
        'event_year': 'Year',
        'age_group': 'Age',
        'location': 'Location',
        'sex': 'Sex',
        'scenario': 'Scenario',
        'measure': 'Measure',
        'metric': 'Metric',
        disease_stage_column: 'Disease Stage',
        'mean': 'Mean',
        'lower': '95% UI Lower',
        'upper': '95% UI Upper',
    }#.update(column_name_map) # This wasn't working for some reason

    disease_stage_name_map = {
        'alzheimers_blood_based_biomarker_state': 'Preclinical AD',
        'alzheimers_mild_cognitive_impairment_state': 'MCI due to AD',
        'alzheimers_disease_state' : 'AD Dementia'
    }
    scenario_name_map = {
        'baseline': 'Reference',
        'bbbm_testing': 'BBBM Testing Only',
        'bbbm_testing_and_treatment' : 'BBBM Testing and Treatment',
    }
    column_order = [
        'Year', 'Location', 'Age', 'Sex' , 'Disease Stage' , 'Scenario',
        'Measure', 'Metric', 'Mean', '95% UI Lower', '95% UI Upper',
    ]
    current_time()
    # Do transformations
    df = (
        df
        # Filter out burn-in years before 2025
        .query('event_year >= 2025')
        # Append rates
        # .pipe(lambda df: df)
        # Scale to real-world values
        .pipe(scale_to_real_world, model_scale, ops)
        .pipe(lambda df: current_time() or df)
        # Summarize data
        .pipe(ops.summarize_draws)
        .reset_index()
        .pipe(lambda df: current_time() or df)
        # Rename columns
        .rename(columns=column_name_map)
        .replace(
            {'Disease Stage': disease_stage_name_map,
             'Scenario': scenario_name_map})
        [column_order]
    )
    return df

# %% [markdown]
# # Deaths and averted deaths

# %%
current_time()
# deaths.entity.unique(): ['alzheimers_disease_state', 'other_causes']
# Filter out other causes when loading since we don't need it
deaths_filter = [('entity', '=', 'alzheimers_disease_state')]
# deaths = load_sim_output('deaths', filters=deaths_filter)

# Stats for reading deaths.parquet:
# 51 seconds to load with 1 location group, 36 MB after concatenation,
# max 939 MB before aggregating seeds
# 60 seconds to load with 3 location groups, 154 MB after concatenation,
# max 306 MB before aggregating seeds
deaths = load_measure_from_batch_runs(
    'deaths', batch_results_dirs, locations, n_location_groups=1, filters=deaths_filter
)
print(len(deaths), 'rows')
print_memory_usage(deaths)
deaths.tail()
# Out:
# 2025-11-02 16:40:18.685857
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_39_18/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 703.901843 MB after read_parquet
# 4.271636 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_41_39/deduplicated_results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 874.541711 MB after read_parquet
# 4.271636 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_45_13/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 938.531843 MB after read_parquet
# 5.693636 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_14_03_51/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 703.901843 MB after read_parquet
# 4.271636 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_16_32_03/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 703.901843 MB after read_parquet
# 4.271636 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_17_25_38/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 703.901843 MB after read_parquet
# 4.271636 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_03_40/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 703.901843 MB after read_parquet
# 4.271636 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_09_31/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 703.901843 MB after read_parquet
# 4.271636 MB after aggregating seeds and converting dtypes
# 35.555636 MB total
# 35.555636 MB after enforcing dtypes
# 1777500 rows
# 35.555636 MB
#         age_group                                      artifact_path  \
# 1777495   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 1777496   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 1777497   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 1777498   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 1777499   95_plus  /mnt/team/simulation_science/pub/models/vivari...
#
#                            entity entity_type  event_year  input_draw measure  \
# 1777495  alzheimers_disease_state       cause        2100         499  deaths
# 1777496  alzheimers_disease_state       cause        2100         499  deaths
# 1777497  alzheimers_disease_state       cause        2100         499  deaths
# 1777498  alzheimers_disease_state       cause        2100         499  deaths
# 1777499  alzheimers_disease_state       cause        2100         499  deaths
#
#                            scenario     sex    value location
# 1777495                    baseline    Male  13502.0   Brazil
# 1777496                bbbm_testing  Female  26597.0   Brazil
# 1777497                bbbm_testing    Male  13502.0   Brazil
# 1777498  bbbm_testing_and_treatment  Female  26801.0   Brazil
# 1777499  bbbm_testing_and_treatment    Male  13598.0   Brazil

# %%
def process_deaths(deaths, ops=ops):
    """Preprocess the deaths dataframe and compute averted deaths."""
    # Filter to only deaths due to AD
    deaths = deaths.query("entity=='alzheimers_disease_state'")
    # Calculate averted deaths
    averted_deaths = (
        ops.averted(deaths, baseline_scenario='baseline')
        .assign(measure='Averted Deaths Associated with AD')
    )
    # Do transformations
    deaths = (
        deaths
        # Rename the measure
        .assign(measure='Deaths Associated with AD')
        # Concatenate deaths with averted deaths
        # TODO: Concatenate with rates also?
        .pipe(lambda df:
              # Use inner join to drop "subtracted_from" column added by
              # .averted
              pd.concat([df, averted_deaths], join='inner', ignore_index=True))
        # Assign same metric to both deaths and averted deaths
        .assign(metric='Number')
        .pipe(convert_to_categorical)
    )
    return deaths

deaths_prepped = process_deaths(deaths)
deaths_prepped.tail()
# Out:
# 49.775504 MB measure
# 16.595504 MB minuend
# 33.185504 MB subtrahend
# 10.674555 MB minuend re-indexed
# 21.339555 MB subtrahend re-indexed
# 21.339615 MB difference
# 37.925636 MB difference with reset index
# 39.110961 MB final difference
#         age_group                                      artifact_path  \
# 2962495   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 2962496   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 2962497   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 2962498   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 2962499   95_plus  /mnt/team/simulation_science/pub/models/vivari...
#
#                            entity entity_type event_year input_draw  \
# 2962495  alzheimers_disease_state       cause       2100        460
# 2962496  alzheimers_disease_state       cause       2100        499
# 2962497  alzheimers_disease_state       cause       2100        499
# 2962498  alzheimers_disease_state       cause       2100        499
# 2962499  alzheimers_disease_state       cause       2100        499
#
#                                    measure                    scenario  \
# 2962495  Averted Deaths Associated with AD  bbbm_testing_and_treatment
# 2962496  Averted Deaths Associated with AD                bbbm_testing
# 2962497  Averted Deaths Associated with AD                bbbm_testing
# 2962498  Averted Deaths Associated with AD  bbbm_testing_and_treatment
# 2962499  Averted Deaths Associated with AD  bbbm_testing_and_treatment
#
#             sex  value location  metric
# 2962495    Male  -93.0   Brazil  Number
# 2962496  Female    0.0   Brazil  Number
# 2962497    Male    0.0   Brazil  Number
# 2962498  Female -204.0   Brazil  Number
# 2962499    Male  -96.0   Brazil  Number

# %% [markdown]
# ## Summarize deaths and save to file

# %%
# 1m 48s to run on first 3 batches of 8.4
deaths_output = summarize_and_beautify(deaths_prepped.query(f"location.isin({locations})"), 'entity')
deaths_output
# Out:
# 2025-11-02 16:41:12.638741
# 2025-11-02 16:41:17.540365
# 2025-11-02 16:42:56.722357
#         Year                  Location       Age     Sex Disease Stage  \
# 0       2025                    Brazil  25_to_29  Female   AD Dementia
# 1       2025                    Brazil  25_to_29    Male   AD Dementia
# 2       2025                    Brazil  25_to_29  Female   AD Dementia
# 3       2025                    Brazil  25_to_29    Male   AD Dementia
# 4       2025                    Brazil  25_to_29  Female   AD Dementia
# ...      ...                       ...       ...     ...           ...
# 113995  2100  United States of America   95_plus    Male   AD Dementia
# 113996  2100  United States of America   95_plus  Female   AD Dementia
# 113997  2100  United States of America   95_plus    Male   AD Dementia
# 113998  2100  United States of America   95_plus  Female   AD Dementia
# 113999  2100  United States of America   95_plus    Male   AD Dementia
#
#                           Scenario                            Measure  Metric  \
# 0                        Reference          Deaths Associated with AD  Number
# 1                        Reference          Deaths Associated with AD  Number
# 2                BBBM Testing Only          Deaths Associated with AD  Number
# 3                BBBM Testing Only          Deaths Associated with AD  Number
# 4       BBBM Testing and Treatment          Deaths Associated with AD  Number
# ...                            ...                                ...     ...
# 113995  BBBM Testing and Treatment          Deaths Associated with AD  Number
# 113996           BBBM Testing Only  Averted Deaths Associated with AD  Number
# 113997           BBBM Testing Only  Averted Deaths Associated with AD  Number
# 113998  BBBM Testing and Treatment  Averted Deaths Associated with AD  Number
# 113999  BBBM Testing and Treatment  Averted Deaths Associated with AD  Number
#
#                Mean  95% UI Lower  95% UI Upper
# 0          0.000000      0.000000      0.000000
# 1          0.000000      0.000000      0.000000
# 2          0.000000      0.000000      0.000000
# 3          0.000000      0.000000      0.000000
# 4          0.000000      0.000000      0.000000
# ...             ...           ...           ...
# 113995  7764.612990   5466.617453  10079.971108
# 113996     0.000000      0.000000      0.000000
# 113997     0.000000      0.000000      0.000000
# 113998   -81.315146   -138.475470    -37.700393
# 113999   -26.827874    -46.417058    -10.244450
#
# [114000 rows x 11 columns]

# %%
# TODO: Check this
deaths_output.loc[
    (deaths_output['Year'] == 2055)
    & (deaths_output['Age'] == '80_to_84')
    & (deaths_output['Sex'] == 'Female')
    & (deaths_output['Disease Stage'] == 'AD Dementia')
    & (deaths_output['Metric'] == 'Number')
    & (deaths_output['Location'] == 'Brazil')
]
# Out:
#        Year Location       Age     Sex Disease Stage  \
# 83900  2055   Brazil  80_to_84  Female   AD Dementia
# 83902  2055   Brazil  80_to_84  Female   AD Dementia
# 83904  2055   Brazil  80_to_84  Female   AD Dementia
# 83906  2055   Brazil  80_to_84  Female   AD Dementia
# 83908  2055   Brazil  80_to_84  Female   AD Dementia
#
#                          Scenario                            Measure  Metric  \
# 83900                   Reference          Deaths Associated with AD  Number
# 83902           BBBM Testing Only          Deaths Associated with AD  Number
# 83904  BBBM Testing and Treatment          Deaths Associated with AD  Number
# 83906           BBBM Testing Only  Averted Deaths Associated with AD  Number
# 83908  BBBM Testing and Treatment  Averted Deaths Associated with AD  Number
#
#                Mean  95% UI Lower  95% UI Upper
# 83900  41516.874234  30009.160489  53911.033448
# 83902  41516.874234  30009.160489  53911.033448
# 83904  40753.025694  29362.896384  53239.191126
# 83906      0.000000      0.000000      0.000000
# 83908    763.848540    461.643850   1154.268147

# %%
deaths_output.to_csv(output_dir / "deaths.csv", index=False)

# %% [markdown]
# # DALYs

# %%
# ylls.entity.unique(): ['alzheimers_disease_state', 'other_causes']
ylls_filter = [('entity', '==', 'alzheimers_disease_state')]
# ylls = load_sim_output('ylls', filters=ylls_filter)

ylls = load_measure_from_batch_runs(
    'ylls', batch_results_dirs, locations, n_location_groups=1, filters=ylls_filter
)
print(len(ylls), 'rows')
print_memory_usage(ylls)
# Out:
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_39_18/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 703.901841 MB after read_parquet
# 4.271634 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_41_39/deduplicated_results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 703.901841 MB after read_parquet
# 4.271634 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_45_13/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 938.531841 MB after read_parquet
# 5.693634 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_14_03_51/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 703.901841 MB after read_parquet
# 4.271634 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_16_32_03/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 703.901841 MB after read_parquet
# 4.271634 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_17_25_38/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 703.901841 MB after read_parquet
# 4.271634 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_03_40/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 703.901841 MB after read_parquet
# 4.271634 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_09_31/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 703.901841 MB after read_parquet
# 4.271634 MB after aggregating seeds and converting dtypes
# 35.555634 MB total
# 35.555634 MB after enforcing dtypes
# 1777500 rows
# 35.555634 MB

# %%
# ylds.entity.unique():
# ['alzheimers_disease_and_other_dementias', 'treatment', 'all_causes']
ylds_filter = [('entity', '==', 'alzheimers_disease_and_other_dementias')]
# ylds = load_sim_output('ylls', filters=ylls_filter)

# Stats for reading ylds.parquet:
# 2m 48s seconds to load with 1 location group, 112 MB after concatenation,
# max 2816 MB before aggregating seeds
# 3m 44s to load with 3 location groups, 466 MB after concatenation,
# max 892 MB before aggregating seeds
ylds = load_measure_from_batch_runs(
    'ylds', batch_results_dirs, locations, n_location_groups=1, filters=ylds_filter
)
print(len(ylds), 'rows')
print_memory_usage(ylds)
# Out:
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_39_18/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 2111.682914 MB after read_parquet
# 13.444865 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_41_39/deduplicated_results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 2623.602782 MB after read_parquet
# 13.444865 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_45_13/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 2815.572914 MB after read_parquet
# 17.924165 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_14_03_51/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 2111.682914 MB after read_parquet
# 13.444865 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_16_32_03/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 2111.682914 MB after read_parquet
# 13.444865 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_17_25_38/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 2111.682914 MB after read_parquet
# 13.444865 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_03_40/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 2111.682914 MB after read_parquet
# 13.444865 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_09_31/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 2111.682914 MB after read_parquet
# 13.444865 MB after aggregating seeds and converting dtypes
# 111.989465 MB total
# 111.989465 MB after enforcing dtypes
# 5332500 rows
# 111.989465 MB

# %%
ylds.tail()
# Out:
#         age_group                                      artifact_path  \
# 5332495   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 5332496   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 5332497   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 5332498   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 5332499   95_plus  /mnt/team/simulation_science/pub/models/vivari...
#
#                                          entity entity_type  event_year  \
# 5332495  alzheimers_disease_and_other_dementias       cause        2100
# 5332496  alzheimers_disease_and_other_dementias       cause        2100
# 5332497  alzheimers_disease_and_other_dementias       cause        2100
# 5332498  alzheimers_disease_and_other_dementias       cause        2100
# 5332499  alzheimers_disease_and_other_dementias       cause        2100
#
#          input_draw measure                    scenario     sex  \
# 5332495         499    ylds  bbbm_testing_and_treatment  Female
# 5332496         499    ylds  bbbm_testing_and_treatment  Female
# 5332497         499    ylds  bbbm_testing_and_treatment    Male
# 5332498         499    ylds  bbbm_testing_and_treatment    Male
# 5332499         499    ylds  bbbm_testing_and_treatment    Male
#
#                                          sub_entity         value location
# 5332495  alzheimers_mild_cognitive_impairment_state    733.931260   Brazil
# 5332496                    alzheimers_disease_state  41801.804723   Brazil
# 5332497      alzheimers_blood_based_biomarker_state      0.000000   Brazil
# 5332498  alzheimers_mild_cognitive_impairment_state    390.033972   Brazil
# 5332499                    alzheimers_disease_state  19666.460225   Brazil

# %%
ylds.entity.unique()
# Out:
# ['alzheimers_disease_and_other_dementias']
# Categories (3, object): ['all_causes', 'alzheimers_disease_and_other_dementias', 'treatment']

# %%
ylls.tail()
# Out:
#         age_group                                      artifact_path  \
# 1777495   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 1777496   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 1777497   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 1777498   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 1777499   95_plus  /mnt/team/simulation_science/pub/models/vivari...
#
#                            entity entity_type  event_year  input_draw measure  \
# 1777495  alzheimers_disease_state       cause        2100         499    ylls
# 1777496  alzheimers_disease_state       cause        2100         499    ylls
# 1777497  alzheimers_disease_state       cause        2100         499    ylls
# 1777498  alzheimers_disease_state       cause        2100         499    ylls
# 1777499  alzheimers_disease_state       cause        2100         499    ylls
#
#                            scenario     sex          value location
# 1777495                    baseline    Male  106200.277260   Brazil
# 1777496                bbbm_testing  Female  211690.810202   Brazil
# 1777497                bbbm_testing    Male  106200.277260   Brazil
# 1777498  bbbm_testing_and_treatment  Female  213301.006534   Brazil
# 1777499  bbbm_testing_and_treatment    Male  106922.406785   Brazil

# %%
ylls.entity.unique()
# Out:
# ['alzheimers_disease_state']
# Categories (2, object): ['alzheimers_disease_state', 'other_causes']

# %%
def process_dalys(ylls, ylds, ops=ops):
    """Process YLLs and YLDs dataframes to get DALYs and averted DALYs.
    """
    # Filter to only YLLs and YLDs due to AD, and rename so the entity
    # is the same between the two, so that the VPHResults object will
    # add YLLs dand YLDs instead of keeping them separate 
    ylls = (
        ylls
        .query("entity=='alzheimers_disease_state'")
        # Choose an arbitrary diseas name
        .replace({'entity': {'alzheimers_disease_state': 'AD'}})
        # Add a sub_entity column to specify disease stage
        .assign(sub_entity='alzheimers_disease_state')
        # Assign 0 YLLs to the MCI state so that when we sum with YLDs,
        # DALYs for MCI will equal YLDs. If we didn't add these 0's, it
        # would just aggregate across disease states instead of keeping
        # them separate.
        .pipe(
            lambda df: pd.concat([df, df.assign(
                sub_entity='alzheimers_mild_cognitive_impairment_state',
                value=0.0
            )])
        )
        .pipe(convert_to_categorical)
    )
    ylds = (
        ylds
        .query("entity=='alzheimers_disease_and_other_dementias'")
        # Choose the same arbitrary diseas name
        .replace({'entity': {'alzheimers_disease_and_other_dementias': 'AD'}})
        .pipe(convert_to_categorical)
    )
    # Create a VPHResults object to calculate DALYs
    results = VPHResults(ylls=ylls, ylds=ylds, ops=ops)
    # Calculate DALYs and compress
    dalys = results.get_burden('dalys').pipe(convert_to_categorical)
    # print_memory_usage(dalys, 'dalys')
    # print(dalys.dtypes)

    # Calculate averted DALYs
    averted_dalys = (
        ops.averted(dalys, baseline_scenario='baseline')
        .assign(measure='Averted DALYs Associated with AD')
    )
    dalys = (
        dalys
        # Rename the measure
        .assign(measure='DALYs Associated with AD')
        # Concatenate deaths with averted DALYs
        # TODO: Concatenate with rates also?
        .pipe(lambda df:
              # Use inner join to drop "subtracted_from" column added by
              # .averted
              pd.concat([df, averted_dalys], join='inner', ignore_index=True))
        # Assign same metric to both DALYs and averted DALYs
        .assign(metric='Number')
        .pipe(convert_to_categorical)
    )
    return dalys

# %%
dalys = process_dalys(ylls, ylds)
print_memory_usage(dalys)
print(len(dalys), 'rows')
dalys.tail()
# Out:
# 101.326919 MB measure
# 48.001787 MB minuend
# 95.994287 MB subtrahend
# 33.782511 MB minuend re-indexed
# 67.555011 MB subtrahend re-indexed
# 67.555071 MB difference
# 67.554419 MB difference with reset index
# 71.109744 MB final difference
# 177.759698 MB
# 8887500 rows
#         age_group                                      artifact_path entity  \
# 8887495   95_plus  /mnt/team/simulation_science/pub/models/vivari...     AD
# 8887496   95_plus  /mnt/team/simulation_science/pub/models/vivari...     AD
# 8887497   95_plus  /mnt/team/simulation_science/pub/models/vivari...     AD
# 8887498   95_plus  /mnt/team/simulation_science/pub/models/vivari...     AD
# 8887499   95_plus  /mnt/team/simulation_science/pub/models/vivari...     AD
#
#         entity_type event_year                           measure     sex  \
# 8887495       cause       2100  Averted DALYs Associated with AD  Female
# 8887496       cause       2100  Averted DALYs Associated with AD  Female
# 8887497       cause       2100  Averted DALYs Associated with AD    Male
# 8887498       cause       2100  Averted DALYs Associated with AD    Male
# 8887499       cause       2100  Averted DALYs Associated with AD    Male
#
#                                          sub_entity input_draw  \
# 8887495                    alzheimers_disease_state        499
# 8887496  alzheimers_mild_cognitive_impairment_state        499
# 8887497      alzheimers_blood_based_biomarker_state        499
# 8887498                    alzheimers_disease_state        499
# 8887499  alzheimers_mild_cognitive_impairment_state        499
#
#                            scenario location        value  metric
# 8887495  bbbm_testing_and_treatment   Brazil -1946.250193  Number
# 8887496  bbbm_testing_and_treatment   Brazil   -14.939114  Number
# 8887497  bbbm_testing_and_treatment   Brazil     0.000000  Number
# 8887498  bbbm_testing_and_treatment   Brazil  -874.528811  Number
# 8887499  bbbm_testing_and_treatment   Brazil    -5.937031  Number

# %% [markdown]
# ## Do some quick checks

# %%
# Verify that DALYs == YLDs except in AD dementia state
df1 = dalys.query("sub_entity!='alzheimers_disease_state' and ~measure.str.contains('Averted')").drop(columns=['entity', 'measure', 'metric'])
df2 = ylds.query("sub_entity!='alzheimers_disease_state'").drop(columns=['entity', 'measure'])
temp = ops.compare_values(df1, df2)
assert len(temp) == 0, 'DALYs differ from YLDs in MCI or BBBM state!'
temp
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Check that DALYs are always greater than YLDs
# 41s to run
df1 = dalys.query("~measure.str.contains('Averted')").drop(columns=['entity', 'measure', 'metric'])
df2 = ylds.drop(columns=['entity', 'measure'])
assert ((ops.value(df1) - ops.value(df2)) >= 0).value.all(), "DALYs are less than YLDs!"

# %% [markdown]
# ## Summarize DALYs and save to file

# %%
# 5m 22s to run on first 3 batches of 8.4 (10 draws)
dalys_output = summarize_and_beautify(dalys)
print_memory_usage(dalys_output)
print(len(dalys_output), 'rows')
dalys_output.tail()
# Out:
# 2025-11-02 16:49:30.111382
# 2025-11-02 16:49:42.114737
# 2025-11-02 16:54:42.455707
# 33.658527 MB
# 342000 rows
#         Year                  Location      Age     Sex   Disease Stage  \
# 341995  2100  United States of America  95_plus  Female     AD Dementia
# 341996  2100  United States of America  95_plus  Female   MCI due to AD
# 341997  2100  United States of America  95_plus    Male  Preclinical AD
# 341998  2100  United States of America  95_plus    Male     AD Dementia
# 341999  2100  United States of America  95_plus    Male   MCI due to AD
#
#                           Scenario                           Measure  Metric  \
# 341995  BBBM Testing and Treatment  Averted DALYs Associated with AD  Number
# 341996  BBBM Testing and Treatment  Averted DALYs Associated with AD  Number
# 341997  BBBM Testing and Treatment  Averted DALYs Associated with AD  Number
# 341998  BBBM Testing and Treatment  Averted DALYs Associated with AD  Number
# 341999  BBBM Testing and Treatment  Averted DALYs Associated with AD  Number
#
#               Mean  95% UI Lower  95% UI Upper
# 341995 -804.790762  -1311.595949   -396.684464
# 341996   -9.375617    -17.798548     -3.687584
# 341997    0.000000      0.000000      0.000000
# 341998 -258.149011   -441.126476   -123.995669
# 341999   -3.182585     -6.759056     -1.061677

# %%
dalys_output.to_csv(output_dir / 'dalys.csv', index=False)

# %% [markdown]
# # Prevalence
#
# Prevalence takes the most time and memory to load because of the
# treatment stratification:
#
# * 27 minutes to load prevalence data from all batches of model 8.4 runs
# * 26 GB to load the largest parquet file using dictionary compression
# * 1.1 GB for final dataframe after aggregating random seeds and
#   converting data types

# %%
# This is the largest dataframe because of the treatment stratification,
# and I don't think we can pre-filter anything. We need to marginalize
# the treatment column, but we have to do that after loading.

# # For testing using model 8.3 data
# person_time_ad = load_sim_output(
#     'person_time_alzheimers_disease_and_other_dementias',
# )

# Load model 8.4 results in batches 11m 10s to load the first 3 batches
# using 1 location group, and the final memory usage was 422 MB. But it
# takes *26 GB* for the largest batch to load all 10 locations in 1
# group.
#
# 26m 29s to load all batches using 1 location group, 1.1 GB for final
# dataframe
person_time_ad = load_measure_from_batch_runs(
    'person_time_alzheimers_disease_and_other_dementias',
    batch_results_dirs, locations, n_location_groups=1
)
print(len(person_time_ad), 'rows')
print_memory_usage(person_time_ad)
person_time_ad.tail()
# Out:
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_39_18/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 19580.95291 MB after read_parquet
# 126.707161 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_41_39/deduplicated_results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 19580.95291 MB after read_parquet
# 126.707161 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_45_13/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 26107.93291 MB after read_parquet
# 168.940561 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_14_03_51/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 19580.95291 MB after read_parquet
# 126.707161 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_16_32_03/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 19580.95291 MB after read_parquet
# 126.707161 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_17_25_38/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 19580.95291 MB after read_parquet
# 126.707161 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_03_40/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 19580.95291 MB after read_parquet
# 126.707161 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_09_31/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 19580.95291 MB after read_parquet
# 126.707161 MB after aggregating seeds and converting dtypes
# 1055.841961 MB total
# 1055.841961 MB after enforcing dtypes
# 47992500 rows
# 1055.841961 MB
#          age_group                                      artifact_path  \
# 47992495   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 47992496   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 47992497   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 47992498   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 47992499   95_plus  /mnt/team/simulation_science/pub/models/vivari...
#
#                                           entity entity_type  event_year  \
# 47992495  alzheimers_disease_and_other_dementias       cause        2100
# 47992496  alzheimers_disease_and_other_dementias       cause        2100
# 47992497  alzheimers_disease_and_other_dementias       cause        2100
# 47992498  alzheimers_disease_and_other_dementias       cause        2100
# 47992499  alzheimers_disease_and_other_dementias       cause        2100
#
#           input_draw      measure                    scenario   sex  \
# 47992495         499  person_time  bbbm_testing_and_treatment  Male
# 47992496         499  person_time  bbbm_testing_and_treatment  Male
# 47992497         499  person_time  bbbm_testing_and_treatment  Male
# 47992498         499  person_time  bbbm_testing_and_treatment  Male
# 47992499         499  person_time  bbbm_testing_and_treatment  Male
#
#                         sub_entity                treatment        value  \
# 47992495  alzheimers_disease_state       waning_effect_long     0.000000
# 47992496  alzheimers_disease_state      waning_effect_short     0.000000
# 47992497  alzheimers_disease_state     no_effect_after_long  3674.880219
# 47992498  alzheimers_disease_state    no_effect_after_short   318.904860
# 47992499  alzheimers_disease_state  no_effect_never_treated  1448.027379
#
#          location
# 47992495   Brazil
# 47992496   Brazil
# 47992497   Brazil
# 47992498   Brazil
# 47992499   Brazil

# %%
person_time_ad.treatment.unique()
# Out:
# ['susceptible_to_treatment', 'waiting_for_treatment', 'full_effect_long', 'full_effect_short', 'waning_effect_long', 'waning_effect_short', 'no_effect_after_long', 'no_effect_after_short', 'no_effect_never_treated']
# Categories (9, object): ['full_effect_long', 'full_effect_short', 'no_effect_after_long', 'no_effect_after_short', ..., 'susceptible_to_treatment', 'waiting_for_treatment', 'waning_effect_long', 'waning_effect_short']

# %%
def process_prevalence_counts(person_time_ad, ops=ops):
    prevalence_counts = (
        person_time_ad
        # Marginalize over treatment column to get total person-time in
        # each AD state
        .pipe(ops.marginalize, 'treatment')
        # Assign measure and metric
        .assign(measure='Prevalence', metric='Number')
        # Save memory if possible
        .pipe(convert_to_categorical)
    )
    return prevalence_counts

# %%
prevalence_counts = process_prevalence_counts(person_time_ad)
print_memory_usage(prevalence_counts)
print(len(prevalence_counts), 'rows')
prevalence_counts.tail()
# Out:
# 106.659631 MB
# 5332500 rows
#         age_group                                      artifact_path  \
# 5332495   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 5332496   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 5332497   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 5332498   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 5332499   95_plus  /mnt/team/simulation_science/pub/models/vivari...
#
#                                          entity entity_type event_year  \
# 5332495  alzheimers_disease_and_other_dementias       cause       2100
# 5332496  alzheimers_disease_and_other_dementias       cause       2100
# 5332497  alzheimers_disease_and_other_dementias       cause       2100
# 5332498  alzheimers_disease_and_other_dementias       cause       2100
# 5332499  alzheimers_disease_and_other_dementias       cause       2100
#
#         input_draw location     measure                    scenario     sex  \
# 5332495        499   Brazil  Prevalence  bbbm_testing_and_treatment  Female
# 5332496        499   Brazil  Prevalence  bbbm_testing_and_treatment  Female
# 5332497        499   Brazil  Prevalence  bbbm_testing_and_treatment    Male
# 5332498        499   Brazil  Prevalence  bbbm_testing_and_treatment    Male
# 5332499        499   Brazil  Prevalence  bbbm_testing_and_treatment    Male
#
#                                          sub_entity          value  metric
# 5332495  alzheimers_mild_cognitive_impairment_state   45459.389459  Number
# 5332496                    alzheimers_disease_state  179500.583162  Number
# 5332497      alzheimers_blood_based_biomarker_state   18701.776865  Number
# 5332498  alzheimers_mild_cognitive_impairment_state   24158.537988  Number
# 5332499                    alzheimers_disease_state   88801.051335  Number

# %%
prevalence_counts.input_draw.nunique(), prevalence_counts.event_year.nunique()
# Out:
# (25, 79)

# %% [markdown]
# ## Summarize prevalence and save to file

# %%
# 1m 29s to run on model 8.3 (5 draws, 36 years)
# 3m 23s to run on first 3 batches of model 8.4 (10 draws, 79 years)
prevalence_output = summarize_and_beautify(prevalence_counts)
print_memory_usage(prevalence_output)
print(len(prevalence_output), 'rows')
prevalence_output.tail()
# Out:
# 2025-11-02 17:21:30.528738
# 2025-11-02 17:21:38.317333
# 2025-11-02 17:24:38.639619
# 20.197304 MB
# 205200 rows
#         Year                  Location      Age     Sex   Disease Stage  \
# 205195  2100  United States of America  95_plus  Female   MCI due to AD
# 205196  2100  United States of America  95_plus  Female     AD Dementia
# 205197  2100  United States of America  95_plus    Male  Preclinical AD
# 205198  2100  United States of America  95_plus    Male   MCI due to AD
# 205199  2100  United States of America  95_plus    Male     AD Dementia
#
#                           Scenario     Measure  Metric           Mean  \
# 205195  BBBM Testing and Treatment  Prevalence  Number   36575.706864
# 205196  BBBM Testing and Treatment  Prevalence  Number  109501.964107
# 205197  BBBM Testing and Treatment  Prevalence  Number   13086.923427
# 205198  BBBM Testing and Treatment  Prevalence  Number   15813.622498
# 205199  BBBM Testing and Treatment  Prevalence  Number   43697.032189
#
#         95% UI Lower   95% UI Upper
# 205195  26113.113289   51261.921242
# 205196  77299.084134  152866.400977
# 205197   7788.450896   18043.014323
# 205198  11258.341829   20361.363153
# 205199  32442.054545   55445.962484

# %%
prevalence_output.Year.nunique()
# Out:
# 76

# %%
prevalence_output.to_csv(output_dir / 'prevalence.csv', index=False)

# %% [markdown]
# # Incidence

# %%
# # Load model 8.3 for testing
# incidence_bbbm = load_sim_output('counts_new_simulants')

# Load model 8.4 in batches
# 14s to load first 3 batches using 1 location group. Max memory 839 MB.
# 17s to load first 3 batches using 3 location groups. Max memory 336
# MB.
# 34s to load all batches, 30 MB for final dataframe
incidence_bbbm = load_measure_from_batch_runs(
    'counts_new_simulants',
    batch_results_dirs, locations, n_location_groups=1
)
print(len(incidence_bbbm), 'rows')
print_memory_usage(incidence_bbbm)
incidence_bbbm.tail()
# Out:
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_39_18/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 618.580986 MB after read_parquet
# 3.631137 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_41_39/deduplicated_results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 789.220854 MB after read_parquet
# 3.631137 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_45_13/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 838.516986 MB after read_parquet
# 4.839837 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_14_03_51/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 618.580986 MB after read_parquet
# 3.631137 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_16_32_03/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 618.580986 MB after read_parquet
# 3.631137 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_17_25_38/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 618.580986 MB after read_parquet
# 3.631137 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_03_40/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 618.580986 MB after read_parquet
# 3.631137 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_09_31/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 618.580986 MB after read_parquet
# 3.631137 MB after aggregating seeds and converting dtypes
# 30.222537 MB total
# 30.222537 MB after enforcing dtypes
# 1777500 rows
# 30.222537 MB
#         age_group                                      artifact_path  \
# 1777495   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 1777496   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 1777497   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 1777498   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 1777499   95_plus  /mnt/team/simulation_science/pub/models/vivari...
#
#          event_year  input_draw                    scenario     sex  value  \
# 1777495        2100         499                    baseline    Male    0.0
# 1777496        2100         499                bbbm_testing  Female    0.0
# 1777497        2100         499                bbbm_testing    Male    0.0
# 1777498        2100         499  bbbm_testing_and_treatment  Female    0.0
# 1777499        2100         499  bbbm_testing_and_treatment    Male    0.0
#
#         location
# 1777495   Brazil
# 1777496   Brazil
# 1777497   Brazil
# 1777498   Brazil
# 1777499   Brazil

# %%
# # Load model 8.3 for testing
# transitions_ad = load_sim_output(
#     'transition_count_alzheimers_disease_and_other_dementias'
# )

# Load model 8.4 results in batches
# 17m 11s to load all batches with all locations in one group
# Maximum 17.4 GB for parquet file before aggregating seeds
# 704 MB for final dataframe
transitions_ad = load_measure_from_batch_runs(
    'transition_count_alzheimers_disease_and_other_dementias',
    batch_results_dirs, locations, n_location_groups=1
)
print(len(transitions_ad), 'rows')
print_memory_usage(transitions_ad)
transitions_ad.tail()
# Out:
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_39_18/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 13053.972908 MB after read_parquet
# 84.473759 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_41_39/deduplicated_results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 13053.972908 MB after read_parquet
# 84.473759 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_29_20_45_13/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 17405.292908 MB after read_parquet
# 112.629359 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_14_03_51/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 13053.972908 MB after read_parquet
# 84.473759 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_16_32_03/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 13053.972908 MB after read_parquet
# 84.473759 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_30_17_25_38/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 13053.972908 MB after read_parquet
# 84.473759 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_03_40/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 13053.972908 MB after read_parquet
# 84.473759 MB after aggregating seeds and converting dtypes
# /mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/results/model8.4/model_spec/2025_10_31_01_09_31/results
# {'United States of America': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', 'Brazil': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', 'China': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', 'Germany': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', 'Israel': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', 'Japan': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', 'Spain': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', 'Sweden': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', 'Taiwan (Province of China)': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', 'United Kingdom': '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'}
# ('artifact_path', 'in', ['/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_states_of_america.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/brazil.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/china.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/germany.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/israel.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/japan.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/spain.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/sweden.hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/taiwan_(province_of_china).hdf', '/mnt/team/simulation_science/pub/models/vivarium_csu_alzheimers/artifacts/model8.3/united_kingdom.hdf'])
# 13053.972908 MB after read_parquet
# 84.473759 MB after aggregating seeds and converting dtypes
# 703.896959 MB total
# 703.896959 MB after enforcing dtypes
# 31995000 rows
# 703.896959 MB
#          age_group                                      artifact_path  \
# 31994995   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 31994996   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 31994997   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 31994998   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 31994999   95_plus  /mnt/team/simulation_science/pub/models/vivari...
#
#                                           entity entity_type  event_year  \
# 31994995  alzheimers_disease_and_other_dementias       cause        2100
# 31994996  alzheimers_disease_and_other_dementias       cause        2100
# 31994997  alzheimers_disease_and_other_dementias       cause        2100
# 31994998  alzheimers_disease_and_other_dementias       cause        2100
# 31994999  alzheimers_disease_and_other_dementias       cause        2100
#
#           input_draw           measure                    scenario   sex  \
# 31994995         499  transition_count  bbbm_testing_and_treatment  Male
# 31994996         499  transition_count  bbbm_testing_and_treatment  Male
# 31994997         499  transition_count  bbbm_testing_and_treatment  Male
# 31994998         499  transition_count  bbbm_testing_and_treatment  Male
# 31994999         499  transition_count  bbbm_testing_and_treatment  Male
#
#                                                  sub_entity  \
# 31994995  alzheimers_mild_cognitive_impairment_state_to_...
# 31994996  alzheimers_mild_cognitive_impairment_state_to_...
# 31994997  alzheimers_mild_cognitive_impairment_state_to_...
# 31994998  alzheimers_mild_cognitive_impairment_state_to_...
# 31994999  alzheimers_mild_cognitive_impairment_state_to_...
#
#                         treatment  value location
# 31994995       waning_effect_long    0.0   Brazil
# 31994996      waning_effect_short    0.0   Brazil
# 31994997     no_effect_after_long  185.0   Brazil
# 31994998    no_effect_after_short   14.0   Brazil
# 31994999  no_effect_never_treated   34.0   Brazil

# %%
transitions_ad.sub_entity.unique()
# Out:
# ['alzheimers_blood_based_biomarker_state_to_alz..., 'alzheimers_mild_cognitive_impairment_state_to...]
# Categories (2, object): ['alzheimers_blood_based_biomarker_state_to_alz..., 'alzheimers_mild_cognitive_impairment_state_to...]

# %%
def process_incidence(incidence_bbbm, transitions_ad, ops=ops):
    incidence_bbbm = (
        incidence_bbbm
        # Assign to_state to match with transition counts dataframe
        # after extracting to and from states from transitions
        .assign(to_state='alzheimers_blood_based_biomarker_state')
    )
    transitions_ad = (
        transitions_ad
        # Display memory usage of loaded dataframe after adding columns
        .pipe(lambda df: print_memory_usage(df, 'raw transitions') or df)
        .pipe(ops.marginalize, 'treatment')
        # Display memory usage of loaded dataframe after adding columns
        .pipe(lambda df: print_memory_usage(df, 'after marginalizing treatment') or df)
        # Extract to and from states from transitions, and add them in
        # new columns
        .pipe(lambda df: df.join(
            cleaning.extract_transition_states(df, 'sub_entity'))
        )
        # Display memory usage of loaded dataframe after adding columns
        .pipe(lambda df: print_memory_usage(df, 'after state extraction') or df)
        .pipe(lambda df: print(df.to_state.unique()) or df)
    )
    incidence = (
        # Concatenate BBBM incidence with MCI and AD incidence
        # Inner join drops irrelevant columns and avoids NaNs
        pd.concat([incidence_bbbm, transitions_ad], join='inner')
        # Assign measure and metric
        .assign(measure='Incidence', metric='Number')
        # Save memory (and time) if possible
        .pipe(convert_to_categorical)
    )
    return incidence

# %%
incidence_counts = process_incidence(incidence_bbbm, transitions_ad)
print(len(incidence_counts), 'rows')
print_memory_usage(incidence_counts)
incidence_counts
# Out:
# 703.896959 MB raw transitions
# 74.660967 MB after marginalizing treatment
# 739.445967 MB after state extraction
# ['alzheimers_mild_cognitive_impairment_state' 'alzheimers_disease_state']
# 5332500 rows
# 138.654125 MB
#         age_group                                      artifact_path  \
# 0        25_to_29  /mnt/team/simulation_science/pub/models/vivari...
# 1        25_to_29  /mnt/team/simulation_science/pub/models/vivari...
# 2        25_to_29  /mnt/team/simulation_science/pub/models/vivari...
# 3        25_to_29  /mnt/team/simulation_science/pub/models/vivari...
# 4        25_to_29  /mnt/team/simulation_science/pub/models/vivari...
# ...           ...                                                ...
# 3554995   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 3554996   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 3554997   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 3554998   95_plus  /mnt/team/simulation_science/pub/models/vivari...
# 3554999   95_plus  /mnt/team/simulation_science/pub/models/vivari...
#
#         event_year input_draw                    scenario     sex    value  \
# 0             2022        169                    baseline  Female      0.0
# 1             2022        169                    baseline    Male      0.0
# 2             2022        169                bbbm_testing  Female      0.0
# 3             2022        169                bbbm_testing    Male      0.0
# 4             2022        169  bbbm_testing_and_treatment  Female      0.0
# ...            ...        ...                         ...     ...      ...
# 3554995       2100        499                bbbm_testing    Male   5701.0
# 3554996       2100        499  bbbm_testing_and_treatment  Female   5343.0
# 3554997       2100        499  bbbm_testing_and_treatment  Female  11028.0
# 3554998       2100        499  bbbm_testing_and_treatment    Male   2999.0
# 3554999       2100        499  bbbm_testing_and_treatment    Male   5791.0
#
#         location                                    to_state    measure  \
# 0          Japan      alzheimers_blood_based_biomarker_state  Incidence
# 1          Japan      alzheimers_blood_based_biomarker_state  Incidence
# 2          Japan      alzheimers_blood_based_biomarker_state  Incidence
# 3          Japan      alzheimers_blood_based_biomarker_state  Incidence
# 4          Japan      alzheimers_blood_based_biomarker_state  Incidence
# ...          ...                                         ...        ...
# 3554995   Brazil                    alzheimers_disease_state  Incidence
# 3554996   Brazil  alzheimers_mild_cognitive_impairment_state  Incidence
# 3554997   Brazil                    alzheimers_disease_state  Incidence
# 3554998   Brazil  alzheimers_mild_cognitive_impairment_state  Incidence
# 3554999   Brazil                    alzheimers_disease_state  Incidence
#
#          metric
# 0        Number
# 1        Number
# 2        Number
# 3        Number
# 4        Number
# ...         ...
# 3554995  Number
# 3554996  Number
# 3554997  Number
# 3554998  Number
# 3554999  Number
#
# [5332500 rows x 11 columns]

# %% [markdown]
# ## Summarize incidence and save to file

# %%
# 1m 33s for model 8.3 (5 draws, 36 years)
# 3m 11s for first 3 batches of model 8.4 (10 draws, 79 years)
incidence_output = summarize_and_beautify(incidence_counts, 'to_state')
print_memory_usage(incidence_output)
print(len(incidence_output), 'rows')
incidence_output.tail()
# Out:
# 2025-11-02 17:42:51.318390
# 2025-11-02 17:42:58.215869
# 2025-11-02 17:45:57.747812
# 20.197303 MB
# 205200 rows
#         Year                  Location      Age     Sex   Disease Stage  \
# 205195  2100  United States of America  95_plus  Female   MCI due to AD
# 205196  2100  United States of America  95_plus  Female     AD Dementia
# 205197  2100  United States of America  95_plus    Male  Preclinical AD
# 205198  2100  United States of America  95_plus    Male   MCI due to AD
# 205199  2100  United States of America  95_plus    Male     AD Dementia
#
#                           Scenario    Measure  Metric         Mean  \
# 205195  BBBM Testing and Treatment  Incidence  Number  4388.829609
# 205196  BBBM Testing and Treatment  Incidence  Number  8277.222182
# 205197  BBBM Testing and Treatment  Incidence  Number     0.000000
# 205198  BBBM Testing and Treatment  Incidence  Number  1977.735942
# 205199  BBBM Testing and Treatment  Incidence  Number  3543.777583
#
#         95% UI Lower  95% UI Upper
# 205195   3100.321938   6523.269216
# 205196   5757.208051  11753.722606
# 205197      0.000000      0.000000
# 205198   1292.244079   2690.301164
# 205199   2467.725323   4565.937331

# %%
incidence_output
# Out:
#         Year                  Location       Age     Sex   Disease Stage  \
# 0       2025                    Brazil  25_to_29  Female  Preclinical AD
# 1       2025                    Brazil  25_to_29  Female   MCI due to AD
# 2       2025                    Brazil  25_to_29  Female     AD Dementia
# 3       2025                    Brazil  25_to_29    Male  Preclinical AD
# 4       2025                    Brazil  25_to_29    Male   MCI due to AD
# ...      ...                       ...       ...     ...             ...
# 205195  2100  United States of America   95_plus  Female   MCI due to AD
# 205196  2100  United States of America   95_plus  Female     AD Dementia
# 205197  2100  United States of America   95_plus    Male  Preclinical AD
# 205198  2100  United States of America   95_plus    Male   MCI due to AD
# 205199  2100  United States of America   95_plus    Male     AD Dementia
#
#                           Scenario    Measure  Metric         Mean  \
# 0                        Reference  Incidence  Number     0.000000
# 1                        Reference  Incidence  Number     0.000000
# 2                        Reference  Incidence  Number     0.000000
# 3                        Reference  Incidence  Number     0.000000
# 4                        Reference  Incidence  Number     0.000000
# ...                            ...        ...     ...          ...
# 205195  BBBM Testing and Treatment  Incidence  Number  4388.829609
# 205196  BBBM Testing and Treatment  Incidence  Number  8277.222182
# 205197  BBBM Testing and Treatment  Incidence  Number     0.000000
# 205198  BBBM Testing and Treatment  Incidence  Number  1977.735942
# 205199  BBBM Testing and Treatment  Incidence  Number  3543.777583
#
#         95% UI Lower  95% UI Upper
# 0           0.000000      0.000000
# 1           0.000000      0.000000
# 2           0.000000      0.000000
# 3           0.000000      0.000000
# 4           0.000000      0.000000
# ...              ...           ...
# 205195   3100.321938   6523.269216
# 205196   5757.208051  11753.722606
# 205197      0.000000      0.000000
# 205198   1292.244079   2690.301164
# 205199   2467.725323   4565.937331
#
# [205200 rows x 11 columns]

# %%
incidence_output.to_csv(output_dir / 'incidence.csv', index=False)

# %% [markdown]
# # Print when notebook finished running
#
# It took about 1h 7m to process all batches of deaths, DALYs, prevalence,
# and incidence data.

# %%
# !date
# Out:
# Sun Nov  2 17:46:02 PST 2025
